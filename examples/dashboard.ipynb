# %%
import panel as pn
from crossfit import dashboard as dash

# pn.extension("vega", sizing_mode='stretch_both')

pn.extension(
    theme='dark',
    template='material',
    sizing_mode='stretch_width'
)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
import panel as pn
import numpy as np
import holoviews as hv

# pn.extension(
#     theme='dark',
#     template='material',
#     sizing_mode='stretch_width'
# )

xs = np.linspace(0, np.pi)

def sine(freq, phase):
    return hv.Curve((xs, np.sin(xs*freq+phase))).opts(
        responsive=True, min_height=400, title="Sine")

def cosine(freq, phase):
    return hv.Curve((xs, np.cos(xs*freq+phase))).opts(
        responsive=True, min_height=400, title="Cosine")

freq = pn.widgets.FloatSlider(name="Frequency", start=0, end=10, value=2)
phase = pn.widgets.FloatSlider(name="Phase", start=0, end=np.pi)


pn.Column(
    pn.pane.Markdown("## Settings"),
    freq,
    phase
)
# Out:
# Column(sizing_mode='stretch_width')
#     [0] Markdown(str, sizing_mode='stretch_width')
#     [1] FloatSlider(end=10, name='Frequency', sizing_mode='stretch_width', value=2)
#     [2] FloatSlider(end=3.141592653589793, name='Phase', sizing_mode='stretch_width')

# %%
auc_metric = dash.Card(
    dash.Text("AUC"),
    dash.Metric("0.9"),
    decoration="top"
)

# auc_metric

# %%
dashboard = dash.TremorDashboard(site_title="Model Performance")
dashboard.main.append(
    auc_metric
)

dashboard.servable()
# Out:
# WARNING:param.TremorDashboard00113: Setting non-parameter attribute site_title=Model Performance using a mechanism intended only for parameters
# TremorDashboard
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [5102873616] Card(collapsible=False, css_classes=['tremor-base', ...], hide_header=True, margin=(10, 5), sizing_mode='stretch_both')
#         [0] HTML(str, margin=(10, 10), sizing_mode='stretch_both')
#         [1] HTML(str, margin=(10, 10), sizing_mode='stretch_both')

# %%
from panel.template import DarkTheme

dark_material = pn.template.MaterialTemplate(title='Material Template', theme=DarkTheme)

# dark_material.sidebar.append(freq)
# dark_material.sidebar.append(phase)

dark_material.main.append(
    pn.Row(
        pn.Card(title='Sine'),
        pn.Card(title='Cosine')
    )
)

dark_material
# Out:
# MaterialTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] MaterialTemplateActions()
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [5294161488] Row(sizing_mode='stretch_both')
#         [0] Card(button_css_classes=['mdc-button', ...], css_classes=['mdc-card'], margin=(10, 5), sizing_mode='stretch_both', title='Sine', title_css_classes=['mdc-card-title'])
#         [1] Card(button_css_classes=['mdc-button', ...], css_classes=['mdc-card'], margin=(10, 5), sizing_mode='stretch_both', title='Cosine', title_css_classes=['mdc-card-title'])
